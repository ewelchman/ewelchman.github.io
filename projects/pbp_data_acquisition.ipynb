# %% [markdown]
# # Get play-by-play data for NFL games
#
# One of the keys to performing any kind of data analysis is to have data in the first place (shocking, I know). For that task, the website Pro Sports Reference provides a great tool for querying huge databases of sports information. The user interface makes it possible to search for pretty much whatever kind of data you want. Football, basketball, college or pro, it's all there. But wouldn't it just be easier if you weren't limited to the website's interface? I think so. So I built a scraper to rebuild Pro Football Reference's ([PFR](www.profootballreference.com)) database of detailed play-by-play information on my own machine.
#
# This notebook aims to strike a middle ground between a pedagogical walkthrough and code documentation. So I'll try and explain the overall picture of what the code aims to do and give extra attention to sections of the code that may not be clear at first glance.
#
# ## Disclaimer
#
# As you read, keep in mind that there are certainly simpler and/or faster ways to accomplish what I'm trying to do. I don't claim to be an expert and this project was in large part a learning exercise.
#
# ## Basic structure
#
# Rebuilding PFR's play-by-play database requires a few steps, which I will briefly outline here:
#
# 1. We need to know how to grab a table from the PFR website. I explain a bit about how to scrape the tables as I go along.
#
# 2. PFR has a lot of information. We need to know exactly which information we want, so that we can figure out where it is and grab it efficiently. I've separated the data gathering into two stages:
#   1. For an individual team and season, get the information about each of their games that season.
#   2. For each of those games, we can then get the relevant play-by-play information.
#
# 3. We need to put all of it into packages that we can easily access later.
#
# ## Initialization and Preamble
#
# Import some packages that we'll be using and define some tables and dictionaries.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import copy

# %% [markdown]
# Make a list of team names, including old ones going back to 1994 or so.

# %%
teams_long = [
    'Atlanta Falcons', 'New Orleans Saints', 'Carolina Panthers','Tampa Bay Buccaneers',
    'New York Giants', 'Dallas Cowboys', 'Philadelphia Eagles', 'Washington Redskins',
    'Minnesota Vikings', 'Green Bay Packers', 'Detroit Lions', 'Chicago Bears',
    'Seattle Seahawks', 'San Francisco 49ers', 'Arizona Cardinals',
    'St. Louis Rams', 'Los Angeles Rams',
    'Pittsburgh Steelers', 'Cleveland Browns', 'Cincinnati Bengals', 'Baltimore Ravens',
    'Buffalo Bills', 'New York Jets', 'Miami Dolphins', 'New England Patriots',
    'Tennessee Titans', 'Jacksonville Jaguars', 'Indianapolis Colts', 'Houston Texans',
    'Houston Oilers', 'Tennessee Oilers',
    'Denver Broncos', 'Oakland Raiders', 'San Diego Chargers', 'Kansas City Chiefs'
]

# %% [markdown]
# We also want a short-form unique identifier for each team. For PFR, these stay the same even when a franchise's branding changes. So the Tennessee Oilers and Tennessee Titans are both represented by 'oti'.

# %%
teams_short = [
    'atl','nor','car','tam','nyg','dal','phi','was',
    'min','gnb','det','chi','sea','sfo','crd','ram',
    'pit','cle','cin','rav','buf','nyj','mia','nwe',
    'oti','jax','clt','htx','den','rai','sdg','kan'
]

# %% [markdown]
# Define a dictionary to translate from the long-form to short-form team name.

# %%
shortform = {
    'Atlanta Falcons':'atl', 'New Orleans Saints':'nor', 
    'Carolina Panthers':'car', 'Tampa Bay Buccaneers':'tam',
    'New York Giants':'nyg', 'Dallas Cowboys':'dal',
    'Philadelphia Eagles':'phi', 'Washington Redskins':'was',
    'Minnesota Vikings':'min', 'Green Bay Packers':'gnb',
    'Detroit Lions':'det', 'Chicago Bears':'chi',
    'Seattle Seahawks':'sea', 'San Francisco 49ers':'sfo',
    'Arizona Cardinals':'crd', 'Los Angeles Rams':'ram', 'St. Louis Rams':'ram',
    'Pittsburgh Steelers':'pit', 'Cleveland Browns':'cle',
    'Cincinnati Bengals':'cin', 'Baltimore Ravens':'rav',
    'Buffalo Bills':'buf', 'New York Jets':'nyj',
    'Miami Dolphins':'mia', 'New England Patriots':'nwe',
    'Tennessee Titans':'oti', 'Jacksonville Jaguars':'jax', 
    'Houston Oilers':'oti', 'Tennessee Oilers':'oti',
    'Indianapolis Colts':'clt', 'Houston Texans':'htx',
    'Denver Broncos':'den', 'Oakland Raiders':'rai',
    'San Diego Chargers':'sdg', 'Kansas City Chiefs':'kan'
}

# %% [markdown]
# Now define a dictionary to get number form of months, which will be useful for making urls for individual games.

# %%
month = {
    'January':'01','February':'02','March':'03','April':'04','May':'05','June':'06',
    'July':'07','August':'08','September':'09','October':'10','November':'11','December':'12'
}

# %% [markdown]
# ## Build functions to parse HTML
#
# We need to be able to deal with raw HTML, which BeautifulSoup can do. This function will take a url and return a soup object containing the HTML.

# %%
def make_soup(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'lxml')
    return soup

# %% [markdown]
# The urls at PFR are formulaic, so we can write a short function to generate the url for a page describing a team's season for a given year

# %%
def season_url(team,year):
    base_url = 'http://www.pro-football-reference.com/teams'
    url = '{0}/{1}/{2}.htm'.format(base_url, team, year)
    return url

# %% [markdown]
# Let's take a look at what we're able to pull out so far.

# %%
soup = make_soup( season_url("cin",2015) )

parsed = soup.findAll(
    'div', {
        'class': 'table_wrapper',
        'id': 'all_games'
    })

print(parsed)
# Out:
# [<div class="table_wrapper" id="all_games">
# <div class="section_heading">
# <span class="section_anchor" data-label="Schedule &amp; Game Results" id="games_link"></span>
# <h2>Schedule &amp; Game Results</h2> <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div> <div class="table_outer_container">
# <div class="overthrow table_container" id="div_games">
# <table class="sortable stats_table" data-cols-to-freeze="1" id="games"><caption>Schedule &amp; Game Results Table</caption>
# <colgroup><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col></colgroup>
# <thead>
# <tr class="over_header">
# <th aria-label="" class=" over_header " colspan="10" data-stat=""></th>
# <th aria-label="" class=" over_header center" colspan="2" data-stat="header_score">Score</th>
# <th aria-label="" class=" over_header center" colspan="5" data-stat="header_off">Offense</th>
# <th aria-label="" class=" over_header center" colspan="5" data-stat="header_def">Defense</th>
# <th aria-label="" class=" over_header center" colspan="3" data-stat="header_exp_pts">Expected Points</th>
# </tr>
# <tr>
# <th aria-label="Week number in season" class=" poptip sort_default_asc sorttable_nosort center" data-stat="week_num" data-tip="Week number in season" scope="col">Week</th>
# <th aria-label="Day" class=" poptip sort_default_asc left" data-stat="game_day_of_week" scope="col">Day</th>
# <th aria-label="Date" class=" poptip sort_default_asc center" data-stat="game_date" scope="col">Date</th>
# <th aria-label="game_time" class=" poptip " data-stat="game_time" scope="col"></th>
# <th aria-label="boxscore_word" class=" poptip sort_default_asc center" data-stat="boxscore_word" scope="col"></th>
# <th aria-label="game_outcome" class=" poptip center" data-stat="game_outcome" scope="col"></th>
# <th aria-label="OT" class=" poptip sort_default_asc left" data-stat="overtime" scope="col">OT</th>
# <th aria-label="Team's record following this game" class=" poptip center" data-stat="team_record" data-tip="Team's record following this game" scope="col">Rec</th>
# <th aria-label="game_location" class=" poptip sort_default_asc center" data-stat="game_location" scope="col"></th>
# <th aria-label="Opp" class=" poptip sort_default_asc center" data-stat="opp" scope="col">Opp</th>
# <th aria-label="Points scored" class=" poptip center" data-over-header="Score" data-stat="pts_off" data-tip="Points scored" scope="col">Tm</th>
# <th aria-label="Points allowed" class=" poptip center" data-over-header="Score" data-stat="pts_def" data-tip="Points allowed" scope="col">Opp</th>
# <th aria-label="1stD" class=" poptip center" data-over-header="Offense" data-stat="first_down_off" scope="col">1stD</th>
# <th aria-label="Total Yards Gained on Offense" class=" poptip center" data-over-header="Offense" data-stat="yards_off" data-tip="Total Yards Gained on Offense" scope="col">TotYd</th>
# <th aria-label="Total Yards Gained by Passing (includes lost sack yardage)" class=" poptip center" data-over-header="Offense" data-stat="pass_yds_off" data-tip="Total Yards Gained by Passing (includes lost sack yardage)" scope="col">PassY</th>
# <th aria-label="Total Yards Gained by Rushing" class=" poptip center" data-over-header="Offense" data-stat="rush_yds_off" data-tip="Total Yards Gained by Rushing" scope="col">RushY</th>
# <th aria-label="Team Turnovers Lost" class=" poptip center" data-over-header="Offense" data-stat="to_off" data-tip="Team Turnovers Lost" scope="col">TO</th>
# <th aria-label="1stD" class=" poptip center" data-over-header="Defense" data-stat="first_down_def" scope="col">1stD</th>
# <th aria-label="Total Yards Allowed by Defense" class=" poptip center" data-over-header="Defense" data-stat="yards_def" data-tip="Total Yards Allowed by Defense" scope="col">TotYd</th>
# <th aria-label="Total Passing Yards Allowed by Defense(includes lost sack yardage)" class=" poptip center" data-over-header="Defense" data-stat="pass_yds_def" data-tip="Total Passing Yards Allowed by Defense&lt;br&gt;(includes lost sack yardage)" scope="col">PassY</th>
# <th aria-label="Total Rushing Yards Allowed by Defense" class=" poptip center" data-over-header="Defense" data-stat="rush_yds_def" data-tip="Total Rushing Yards Allowed by Defense" scope="col">RushY</th>
# <th aria-label="Turnovers Gained by Defense" class=" poptip center" data-over-header="Defense" data-stat="to_def" data-tip="Turnovers Gained by Defense" scope="col">TO</th>
# <th aria-label="Offense" class=" poptip " data-over-header="Expected Points" data-stat="exp_pts_off" scope="col">Offense</th>
# <th aria-label="Defense" class=" poptip " data-over-header="Expected Points" data-stat="exp_pts_def" scope="col">Defense</th>
# <th aria-label="Sp. Tms" class=" poptip " data-over-header="Expected Points" data-stat="exp_pts_st" scope="col">Sp. Tms</th>
# </tr>
# </thead>
# <tbody><tr><th class="right " csk="1" data-stat="week_num" scope="row">1</th><td class="left " data-stat="game_day_of_week">Sun</td><td class="left " csk="2015-09-13" data-stat="game_date">September 13</td><td class=" " csk="16.25" data-stat="game_time">4:25PM ET</td><td class="center " data-stat="boxscore_word"><a href="/boxscores/201509130rai.htm">boxscore</a></td><td class="right " data-stat="game_outcome">W</td><td class="left " data-stat="overtime"></td><td class="center " data-stat="team_record
><td class="right " data-stat="game_location"></td><td class="left " data-stat="opp"><a href="/teams/rav/2015.htm">Baltimore Ravens</a></td><td class="right " data-stat="pts_off">24</td><td class="right " data-stat="pts_def">16</td><td class="right " data-stat="first_down_off">17</td><td class="right " data-stat="yards_off">292</td><td class="right " data-stat="pass_yds_off">147</td><td class="right " data-stat="rush_yds_off">145</td><td class="right " data-stat="to_off"></td><td class="right " data-stat="first_down_def">22</td><td class="right " data-stat="yards_def">341</td><td class="right " data-stat="pass_yds_def">282</td><td class="right " data-stat="rush_yds_def">59</td><td class="right " data-stat="to_def">2</td><td class="right " data-stat="exp_pts_off">2.50</td><td class="right " data-stat="exp_pts_def">7.44</td><td class="right " data-stat="exp_pts_st">1.74</td></tr>
# <tr><th class="right " csk="16.5" data-stat="week_num" scope="row"></th><td class="left " data-stat="game_day_of_week"></td><td class="left " data-stat="game_date"><strong>Playoffs</strong></td><td class=" " data-stat="game_time"></td><td class="center " data-stat="boxscore_word"></td><td class="right " data-stat="game_outcome"></td><td class="left " data-stat="overtime"></td><td class="center " data-stat="team_record"></td><td class="right " data-stat="game_location"></td><td class="left " data-stat="opp"></td><td class="right " data-stat="pts_off"></td><td class="right " data-stat="pts_def"></td><td class="right " data-stat="first_down_off"></td><td class="right " data-stat="yards_off"></td><td class="right " data-stat="pass_yds_off"></td><td class="right " data-stat="rush_yds_off"></td><td class="right " data-stat="to_off"></td><td class="right " data-stat="first_down_def"></td><td class="right " data-stat="yards_def"></td><td class="right " data-stat="pass_yds_def"></td><td class="right " data-stat="rush_yds_def"></td><td class="right " data-stat="to_def"></td><td class="right " data-stat="exp_pts_off"></td><td class="right " data-stat="exp_pts_def"></td><td class="right " data-stat="exp_pts_st"></td></tr>
# <tr><th class="right " csk="17" data-stat="week_num" scope="row">Wild Card</th><td class="left " data-stat="game_day_of_week">Sat</td><td class="left " csk="2016-01-09" data-stat="game_date">January 9</td><td class=" " csk="20.15" data-stat="game_time">8:15PM ET</td><td class="center " data-stat="boxscore_word"><a href="/boxscores/201601090cin.htm">boxscore</a></td><td class="right " data-stat="game_outcome">L</td><td class="left " data-stat="overtime"></td><td class="center " data-stat="team_record">12-5</td><td class="right " data-stat="game_location"></td><td class="left " data-stat="opp"><a href="/teams/pit/2015.htm">Pittsburgh Steelers</a></td><td class="right " data-stat="pts_off">16</td><td class="right " data-stat="pts_def">18</td><td class="right " data-stat="first_down_off">19</td><td class="right " data-stat="yards_off">279</td><td class="right " data-stat="pass_yds_off">188</td><td class="right " data-stat="rush_yds_off">91</td><td class="right " data-stat="to_off">4</td><td class="right " data-stat="first_down_def">21</td><td class="right " data-stat="yards_def">369</td><td class="right " data-stat="pass_yds_def">202</td><td class="right " data-stat="rush_yds_def">167</td><td class="right " data-stat="to_def">2</td><td class="right " data-stat="exp_pts_off">-10.48</td><td class="right " data-stat="exp_pts_def">4.17</td><td class="right " data-stat="exp_pts_st">3.85</td></tr>
# </tbody></table>
# </div>
# </div>
# </div>]

# %% [markdown]
# This is a bit scary to look at, but BeautifulSoup can help us out quite a bit.
#
# The next function first reads the rows of the table and then picks out the header. Once we have the header and each individual row, we can make a pandas dataframe from our table. The dataframes make the data much easier to handle for bulk operations and we'll want to turn tables into dataframes wherever possible.

# %%
def make_season_df(team, year):

    # Make soup object for the team's season page
    soup = make_soup( season_url( team, year ) )
    
    # Pull out the table with the schedule
    try:
        parsed = soup.findAll(
            'div', {
                'class': 'table_wrapper',
                'id': 'all_games'
            })
    except:
        return 0
    
    
    # From that table, pull out the rows
    try:
        rows = parsed[0].findAll('tr')
    except:
        return 0
    
    # Separate the list of rows into their constituent elements,
    # resulting in a 2-dimensional array
    season_data = [
        [td.getText() for td in rows[i].findAll(['td','th'])] for i in range(len(rows))
    ]
    
    
    # Re-write a couple column titles in forms pandas can handle
    season_data[1][3:6] = ['Time','boxscore','result']
    season_data[1][8] = 'homeaway'
    season_data[1][10] = 'tm_score'
    season_data[1][11] = 'opp_score'
    
    # And finally make the dataframe
    season_df = pd.DataFrame( season_data[2:], columns=season_data[1] )
    
    return season_df

# %% [markdown]
# Let's check what this returns by looking at Carolina's 2015 season.

# %%
df = make_season_df( "car", 2015 )
df.head(5)
# Out:
#   Week  Day          Date       Time  boxscore result OT  Rec homeaway  \
# 0    1  Sun  September 13  1:03PM ET  boxscore      W     1-0        @
# 1    2  Sun  September 20  1:02PM ET  boxscore      W     2-0
# 2    3  Sun  September 27  1:03PM ET  boxscore      W     3-0
# 3    4  Sun     October 4  1:03PM ET  boxscore      W     4-0        @
# 4    5
#
#                     Opp   ...   RushY TO 1stD TotYd PassY RushY TO Offense  \
# 0  Jacksonville Jaguars   ...     105  1   18   265   169    96  3   -5.98
# 1        Houston Texans   ...     172  1   21   300   239    61  1    2.49
# 2    New Orleans Saints   ...     119      27   380   310    70  2   20.67
# 3  Tampa Bay Buccaneers   ...     133  1   25   411   270   141  5    3.28
# 4              Bye Week   ...
#
#   Defense Sp. Tms
# 0   18.45    0.05
# 1    7.98   -3.79
# 2   -9.37   -5.11
# 3    4.42    6.73
# 4
#
# [5 rows x 25 columns]

# %% [markdown]
# That looks pretty good! All of the source columns are present. All that's left to do is add which team and season the table is for so that we can recognize them once we put a bunch of these dataframes together.
#
# Once we've done that, we want to figure out where to find the play-by-play data for each of these games. For PFR, this requires getting the date of the game and the short-form name of the home team. I get it for each game by applying a function to each row in the dataframe. The way it's written here, that requires creating a series for each row, which is not particularly efficient.

# %%
def contextualized_season(season_df, team, year):
    # Make a column for the season year and team
    season_df['team'] = team
    season_df['season'] = year

    # Make the url segment where we can find the box score for this game
    def make_boxscore_url(game,team,year):
        try:
            mn, day = str(game.Date).split()
            mn = month[mn]
            day = day.zfill(2)  # fill rest of string length 2 with zeros
            for tm in teams_long:
                if tm in str(game.Opp):
                    opponent = shortform[ tm ]
                    break
            location = team
            
            if int(mn) <= 3:
                year = int(year)+1
            if "@" in str(game.homeaway):
                location = opponent
                
            url_seg = "{0}{1}{2}0{3}".format(year,mn,day,location)
            return url_seg
        
        except:
            return "bye"

    season_df['box_url'] = season_df.apply( 
                    lambda row: make_boxscore_url(row,team,year), 
                    axis=1 )
    
    return season_df

# %% [markdown]
# So now we can put all of these little pieces together.

# %%
def grab_season(team, year):
    
    df = make_season_df( team, year )
    
    # A failure above will result in returning 0 for df.
    # Allow for failed grab without crashing loops later on
    if not type(df) is int:
        df = contextualized_season( df, team, year )
    
    return df

# %% [markdown]
# And we can loop over that for each team and season of interest. For the purpose of building the play-by-play dataset, PFR has detailed play-by-play data for most games 1995 and later, so the code here can be easily modified to loop over each team for each year since 1995.

# %%
season_list = []

for yr in range(1996,2016):
    for tm in teams_short:
        print(str(tm)+" "+str(yr))
        
        # Try to make a dataframe for this team this season
        season_df = grab_season( tm, yr )
        
        # If that was successful, add it to the list of dataframes
        if type(season_df) is int:
            pass
        else:
            season_list.append(season_df)
            
        # Wait between pings so we don't get blocked
        time.sleep(1)
        
# And concatenate all of our dataframes into one big table
games_df = pd.concat( season_list )
# Out:
# atl 1996
# nor 1996
# car 1996
# tam 1996
# nyg 1996
# dal 1996
# phi 1996
# was 1996
# min 1996
# gnb 1996
# det 1996
# chi 1996
# sea 1996
# sfo 1996
# crd 1996
# ram 1996
# pit 1996
# cle 1996
# cin 1996
# rav 1996
# buf 1996
# nyj 1996
# mia 1996
# nwe 1996
# oti 1996
# jax 1996
# clt 1996
# htx 1996
# den 1996
# rai 1996
# sdg 1996
# kan 1996
# atl 1997
# nor 1997
# car 1997
# tam 1997
# nyg 1997
# dal 1997
# phi 1997
# was 1997
# min 1997
# gnb 1997
# det 1997
# chi 1997
# sea 1997
# sfo 1997
# crd 1997
# ram 1997
# pit 1997
# cle 1997
# cin 1997
# rav 1997
# buf 1997
# nyj 1997
# mia 1997
# nwe 1997
# oti 1997
# jax 1997
# clt 1997
# htx 1997
# den 1997
# rai 1997
# sdg 1997
# kan 1997
# atl 1998
# nor 1998
# car 1998
# tam 1998
# nyg 1998
# dal 1998
# phi 1998
# was 1998
# min 1998
# gnb 1998
# det 1998
# chi 1998
# sea 1998
# sfo 1998
# crd 1998
# ram 1998
# pit 1998
# cle 1998
# cin 1998
# rav 1998
# buf 1998
# nyj 1998
# mia 1998
# nwe 1998
# oti 1998
# jax 1998
# clt 1998
# htx 1998
# den 1998
# rai 1998
# sdg 1998
# kan 1998
# atl 1999
# nor 1999
# car 1999
# tam 1999
# nyg 1999
# dal 1999
# phi 1999
# was 1999
# min 1999
# gnb 1999
# det 1999
# chi 1999
# sea 1999
# sfo 1999
# crd 1999
# ram 1999
# pit 1999
# cle 1999
# cin 1999
# rav 1999
# buf 1999
# nyj 1999
# mia 1999
# nwe 1999
# oti 1999
# jax 1999
# clt 1999
# htx 1999
# den 1999
# rai 1999
# sdg 1999
# kan 1999
# atl 2000
# nor 2000
# car 2000
# tam 2000
# nyg 2000
# dal 2000
# phi 2000
# was 2000
# min 2000
# gnb 2000
# det 2000
# chi 2000
# sea 2000
# sfo 2000
# crd 2000
# ram 2000
# pit 2000
# cle 2000
# cin 2000
# rav 2000
# buf 2000
# nyj 2000
# mia 2000
# nwe 2000
# oti 2000
# jax 2000
# clt 2000
# htx 2000
# den 2000
# rai 2000
# sdg 2000
# kan 2000
# atl 2001
# nor 2001
# car 2001
# tam 2001
# nyg 2001
# dal 2001
# oti 2014
# jax 2014
# clt 2014
# htx 2014
# den 2014
# rai 2014
# sdg 2014
# kan 2014
# atl 2015
# nor 2015
# car 2015
# tam 2015
# nyg 2015
# dal 2015
# phi 2015
# was 2015
# min 2015
# gnb 2015
# det 2015
# chi 2015
# sea 2015
# sfo 2015
# crd 2015
# ram 2015
# pit 2015
# cle 2015
# cin 2015
# rav 2015
# buf 2015
# nyj 2015
# mia 2015
# nwe 2015
# oti 2015
# jax 2015
# clt 2015
# htx 2015
# den 2015
# rai 2015
# sdg 2015
# kan 2015

# %%
games_df.to_csv("game_info.csv")

# %%
games_df = pd.read_csv("game_info.csv")

# %% [markdown]
# ## Getting the play-by-play for a single game

# %% [markdown]
# Despite BeautifulSoup being pretty good at handling HTML, I had problems consistently parsing the play-by-play tables from PFR and wound up doing a lot of it "by hand." That is to say that the bits of code for reading the tables aren't very pretty, but they do work.
#
# The first order of business is to read a table header. Given the relevant text from the HTML, this function will do just that. As a bonus, the header might tell us who the home and away teams are, which we'll need to use to figure out which team has the ball on each play.

# %%
def read_header(txt):
    """Tries to read a header from a given input string of HTML text
    
    Returns a tuple consisting of a list of column titles as well as
    the home and away teams"""
    
    header = []
    home_team = 0
    away_team = 0

    # Cycle through each chunk in the raw HTML text
    
    # Look at each section of txt
    for section in txt:
        # For each chunk in that section
        for chunk in section.split():
            
            # Check whether this is the name of a statistic
            # If so, add it to the header
            if "data-stat" in chunk:
                header.append( chunk.split("=")[1].strip('"') )
                
            # This may be home/away team info
            if "</th>" in chunk:
                # strip html tags from the chunk
                chars = chunk.replace("</th","").strip(">")
                
                if "pbp_score_aw" in header[len(header)-1]:
                    away_team = chars                
                elif "pbp_score_hm" in header[len(header)-1]:
                    home_team = chars
                    
            # Or maybe we've reached the end of the header
            elif "</thead>" in chunk:
                break
            elif "</tr>" in chunk:
                break
                
                
    return header, home_team, away_team

# %% [markdown]
# Now that we have the header, we'll want to also read the entries for the rest of the table.
#
# The code gets a bit ugly here, but the main idea is this: within the tags denoting each table entry, the displayed content is the only text not contained within additional html tags. So what the code does is to separate and list each of the tags in a single row (corresponding to one play) and make a separate list for everything that fits in between those tags, giving us the content of the entries in the row.
#
# In addition, each of these rows may contain tags indicating which players are involved in the play, whether the previous play resulted in a change of possession, and whether the play resulted in a score. So the code checks for those as well.

# %%
def read_table(soup, table):
    """
    Reads a given soup object to find a play-by-play table.
    
    Returns a pandas dataFrame containing the table contents.
    """
    # Differentiate if we're looking for play-by-play table or the spread
    if table == "pbp":
        tablename = "all_pbp"
    elif table == "gameinfo":
        tablename = "all_game_info"
    else:
        tablename = table
        
    
    # Extract the HTML for the "all_pbp" table
    table = soup.find(
        'div', {
            'id': tablename
        })
    
    # If there's no text here, just return 0
    try:
        txt = table.findAll(text=True)
    except:
        return 0
    
    
    # Read the table header directly
    header, home_team, away_team = read_header(txt)
    
    # Turn rows back into strings
    rows = []
    table_body = False
    rowstring = ""
    for section in txt:
        for i, chunk in enumerate(section.split()):
            if ("<tbody>" in chunk) or ("<tr" in chunk):
                table_body = True
            if table_body:
                rowstring += " "+chunk
                if "</tr" in chunk:
                    rows.append(rowstring)
                    rowstring = ""
            if ("</tbody>" in chunk) or ("</table>" in chunk):
                break
                
    # Find data from spaces between tags in each of the rows
    all_entries = []
    stat_names = []
    players_involved = []
    change_of_possession = []
    scoring_plays = []
    in_tag = False
    en_str = ""
    tag_str = ""
    for r, row_string in enumerate(rows):
    
        # Tag-ify the row
        row_en = []
        row_tags = []
        for i, c in enumerate(row_string):
            if c == '<':
                in_tag = True
                row_en.append(en_str)
                en_str = ""
            if not in_tag:
                en_str += c
            elif in_tag:
                tag_str += c
            if c == '>':
                in_tag = False
                row_tags.append(tag_str)
                tag_str = ""
            
        # Make a list of entries in the row
        row_entries = []
        for i, tag in enumerate(row_tags):
            entry = ""
            if ('<th' in tag or '<td' in tag):
                finished = False
                while not finished:
                    for j in range(i,len(row_tags)):
                        entry += row_en[j]
                        if ('/th>' in row_tags[j] or '/td' in row_tags[j]):
                            finished = True
                            break
                row_entries.append(entry)
            
        # Add these entries to the list of all entries
        all_entries.append(row_entries)
            
        # Make a list of players involved in the play
        names = []
        for i, tag in enumerate(row_tags):
            if 'href' in tag:
                names.append(row_en[i+1])
        players_involved.append(names)
        
        # Check for whether play has a change of possession
        change_of_possession.append(0)
        if 'class="divider"' in row_string:
            # Previous play had a change of possession
            change_of_possession[r-1] = 1
            
        # Check for scoring plays
        if 'class=" score"' in row_string:
            scoring_plays.append(1)
        else:
            scoring_plays.append(0)
            
        
        # Make a new header to compare with one from above
        if r == 2:  #this should work but may need to change eventually
            for tag in row_tags:
                for term in tag.split():
                    if "data-stat" in term:
                        stat_names.append( term.split("=")[1].strip('"') )
                  
                
    if tablename == "all_pbp":
        # Add column for players involved
        header.append("players_involved")
        header.append("scoring_play")
        header.append("change_of_poss")
        stat_names.append("players_involved")
        stat_names.append("scoring_play")
        stat_names.append("change_of_poss")
        for i, play in enumerate(all_entries):
            play.append(", ".join(players_involved[i]))
            play.append(scoring_plays[i])
            play.append(change_of_possession[i])
            
        
    # Make a pandas DataFrame from the header and entries
    try:
        df = pd.DataFrame( all_entries, columns=header )
    except:
        df = pd.DataFrame( all_entries, columns=stat_names )
        
    
    # Add home and away team to dataframe
    if type(home_team) is not int:
        df['home_team'] = home_team
        df['away_team'] = away_team
    
        
    return df

# %% [markdown]
# If there's anywhere in this notebook that could be duplicated much more easily/simply, this is it. The source code for the detailed play-by-play table has a few extra fancy features that mean we can't parse them the same way as we did the team/year schedule tables. I've read that the HTML5lib module should be able to handle the sort of table that we're looking at, so that's a place to start simplifying the above code.
#
# But if it works, we can move forward without worrying too much about how pretty the code is. So let's check that it all works.
#
# First, write a function to complete the boxscore url from whence to grab play-by-play data, then try reading that table for a particular game. In this case, look at the first 10 rows in the play-by-play table for the Bengals-Steelers game on December 13, 2015.

# %%
def boxscore_url(url):
    base_url = "http://www.pro-football-reference.com/boxscores"
    whole_url = "{0}/{1}.htm".format(base_url,url)
    return whole_url

# %%
pbp_soup = make_soup(boxscore_url("201512130cin"))
pbp_df = read_table(pbp_soup,"pbp")

# %%
pbp_df.head(10)
# Out:
#        quarter qtr_time_remain   down yds_to_go   location  \
# 0      Quarter            Time   Down      ToGo   Location
# 1  1st Quarter                      0         0       None
# 2            1           15:00                      CIN 35
# 3            1           15:00      1        10     PIT 20
# 4            1           14:15      2         8     PIT 22
# 5            1           13:39      3         1     PIT 29
# 6            1           13:31      1        10     CIN 40
# 7            1           12:47      2         7     CIN 37
# 8            1           12:05      3         7     CIN 37
# 9            1           11:54      1        10     CIN 27
#
#                                               detail pbp_score_aw  \
# 0                                             Detail          PIT
# 1                                               None         None
# 2          Mike Nugent kicks off 65 yards, touchback            0
# 3  DeAngelo Williams middle for 2 yards (tackle b...            0
# 4  Ben Roethlisberger pass complete short left to...            0
# 5  Ben Roethlisberger pass complete deep right to...            0
# 6  DeAngelo Williams left guard for 3 yards (tack...            0
# 7  Ben Roethlisberger pass complete short left to...            0
# 8  Ben Roethlisberger pass complete short left to...            0
# 9  DeAngelo Williams right end for no gain (tackl...            0
#
#   pbp_score_hm exp_pts_before exp_pts_after home_wp  \
# 0          CIN            EPB           EPA    Win%
# 1         None           None          None    None
# 2            0              0         -0.28    56.6
# 3            0           0.28             0    57.4
# 4            0              0          0.23    56.6
# 5            0           0.23          2.92    48.6
# 6            0           2.92          2.78    49.0
# 7            0           2.78          2.08    51.0
# 8            0           2.08          3.78    45.7
# 9            0           3.78          3.23    47.4
#
#                                     players_involved  scoring_play  \
# 0                                                              0.0
# 1                                               None           NaN
# 2                                        Mike Nugent           0.0
# 3                 DeAngelo Williams, Vontaze Burfict           0.0
# 4  Ben Roethlisberger, Heath Miller, Vincent Rey,...           0.0
# 5                 Ben Roethlisberger, Markus Wheaton           0.0
# 6                 DeAngelo Williams, Vontaze Burfict           0.0
# 7                Ben Roethlisberger, Martavis Bryant           0.0
# 8   Ben Roethlisberger, Heath Miller, Emmanuel Lamur           0.0
# 9                 DeAngelo Williams, Michael Johnson           0.0
#
#    change_of_poss home_team away_team
# 0             0.0       CIN       PIT
# 1             NaN       CIN       PIT
# 2             1.0       CIN       PIT
# 3             0.0       CIN       PIT
# 4             0.0       CIN       PIT
# 5             0.0       CIN       PIT
# 6             0.0       CIN       PIT
# 7             0.0       CIN       PIT
# 8             0.0       CIN       PIT
# 9             0.0       CIN       PIT

# %% [markdown]
# Also, I've built the above function with enough versatility that it can pick out whichever table from the webpage that we want, assuming we know what it's called. For instance, I'll try pulling out the table containing the Vegas spread.

# %%
spread_df = read_table(pbp_soup,"gameinfo")
print(spread_df)
# Out:
#          info                                               stat
# 0   Game Info                                               None
# 1    Won Toss                                           Steelers
# 2        Roof                                           outdoors
# 3     Surface                                         fieldturf
# 4     Weather  63 degrees relative humidity 79%, wind 8 mph, ...
# 5  Vegas Line                            Cincinnati Bengals -2.5
# 6  Over/Under                                        50.0 (over)

# %%
sp_df = spread_df[ spread_df['info'].str.contains("Vegas") ]
print(sp_df.values[0,1])
#spread = spread_df.ix[5,'stat']
# Out:
# Cincinnati Bengals -2.5

# %% [markdown]
# We'll use this later to include the predicted spread in the information for this game

# %% [markdown]
# ## Clean/Massage the data a little bit
#
# Since the data will eventually be used, it's going to need a little bit of manipulation before that can happen. For instance, it might be useful for the row representing each play to be completely self-contained so that it doesn't rely on any other rows for context.
#
# To see why that matters, consider trying to use the game situation before a given play to try and predict which team will win the game. The row contains information for the quarter, time remaining, down and distance and field position as well as some other things, but doesn't say which team has the ball. We would want to know that before trying to predict a winner, especially close to the end of the game.
#
# The scores given in the PFR tables are also after the play has been completed, where our prediction would be based on the score before the play. The score before the play can be grabbed from the row for the previous play, but then each is no longer self-contained, so considerations like that are important before we try and do too much with our data.
#
# In any case, one of the first things to do is drop rows that aren't associated with plays. One way to do that is to make a list of which rows satisfy a given condition and then filter the dataframe accordingly.

# %%
def drop_nonplays(df):
    
    # Take out rows for the start of quarters/OT
    bool_list = [ not i for i in df['quarter'].str.contains("Quarter") ]
    df = df.loc[ bool_list ]
    
    bool_list = [ not i for i in df['quarter'].str.contains("End") ]
    df = df.loc[ bool_list ]
    
    bool_list = [ not i for i in df['quarter'].str.contains("Overtime") ]
    df = df.loc[ bool_list ]
    
    # Take out rows for Coach's challenges and timeouts
    bool_list = [ not i for i in df['detail'].str.contains("challenged") ]
    df = df.loc[ bool_list ]
    
    bool_list = [ not i for i in df['detail'].str.contains("Timeout") ]
    df = df.loc[ bool_list ]
    
    return df

# %% [markdown]
# Now that all of the remaining rows signify plays, we might be able to figure out who has the ball for each play. I found this to be a surprisingly tricky problem to solve since the table contains very little information about which team is which.
#
# But we *do* know the score for the home and away team after each play, so we should be able to tell which team had possession on that play, and we *do* know when the ball changes hands. So unless the game is a scoreless tie, we can assign possession by figuring out who scored first and working in either direction to the beginning or end of the game from there.
#
# But there's a catch! We can't simply assume that the offense scored the first points in the game; it could have been the defense or special teams. So we'll need to check the play details to see whether the scoring team had possession at the beginning of the play. The function below does that by checking the play details for a few trigger terms that most likely mean that the defense or punt/kickoff return team scored. This method isn't foolproof, but should be correct in almost all cases.

# %%
def assign_possession(df):
    """
    Return a list of whether home/away team has possession for each play
    """
    
    # Make sure columns are integers i.e. mathematically comparable
    df['scoring_play'] = df['scoring_play'].astype(int)
    df['pbp_score_aw'] = df['pbp_score_aw'].astype(int)
    df['pbp_score_hm'] = df['pbp_score_hm'].astype(int)
    
    # Set up some lists/arrays to iterate through
    scores = df['scoring_play'].values
    change_of_poss = df['change_of_poss'].values
    details = [str(i) for i in df['detail'].values]
    possession = ["xxx" for i in scores]
    
    # Get i for which ith row is the first score
    # This returns the index of the first instance of 1 in a numpy array
    first_score_idx = scores.tolist().index(1)
    
    
    # Check if there are triggers indicating defensive scores on the play
    triggers = ["fumbles", "intercepted", "kicks off", "punts ", " safety"]
    num_triggers = sum(
            [ 1 for s in triggers if s in details[first_score_idx] ]
        )
    
    # If home team scored first
    if df['pbp_score_hm'].values[first_score_idx] != 0:
        if num_triggers != 0:
            # First score was very probably by defense/return team
            possession[first_score_idx] = "away"
        else:
            possession[first_score_idx] = "home"
    
    else: # Away team scored first
        if num_triggers != 0:
            # First score was very probably by defense/return team
            possession[first_score_idx] = "home"
        else:
            possession[first_score_idx] = "away"
            
            
    # For plays prior to the first score,
    # trace possession arrow to the start of the game
    for p in range(first_score_idx):
        known_play = first_score_idx - p
        prev_play = first_score_idx - (p+1)
        
        if change_of_poss[prev_play] == 0: # No change of possession
            possession[prev_play] = possession[known_play]
            
        # otherwise, ball changed hands
        elif possession[known_play] == "home":
            possession[prev_play] = "away"
        elif possession[known_play] == "away":
            possession[prev_play] = "home"

            
    # Now do the same from the first score to end of game
    for p in range( first_score_idx, len(scores)-1 ):
        
        if change_of_poss[p] == 0: # No change of possession
            possession[p+1] = possession[p]
            
        elif possession[p] == "home":
            possession[p+1] = "away"
        elif possession[p] == "away":
            possession[p+1] = "home"
        
    
    return possession

# %%
df = drop_nonplays(pbp_df)
poss_list = assign_possession(df)
print(poss_list[:25])
# Out:
# ['home', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'home', 'home', 'home', 'home', 'home', 'home', 'home', 'home', 'home', 'away', 'away']

# %% [markdown]
# I also mentioned getting the score before each play. We can get that by simply grabbing the score from the previous play.

# %%
def get_score_before_plays(df):
    
    # Get scores from the previous plays
    df['home_score'] = df.pbp_score_hm.shift(1)
    df['away_score'] = df.pbp_score_aw.shift(1)

    # Still need to add score 0-0 for the first play
    df['home_score'].iloc[0] = 0
    df['away_score'].iloc[0] = 0

# %% [markdown]
# In the interest of giving each play context, it may also be useful to add a column for which team wins the game.

# %%
def get_winner(df):
    """Return whether the home/away team wins the game"""
    last_play = df.tail(1)
    score_diff = int(last_play.pbp_score_hm) - int(last_play.pbp_score_aw)
    if score_diff > 0:
        return "home"
    elif score_diff < 0:
        return "away"
    else:
        return "tie"

# %% [markdown]
# There are also a couple of things that I want to do in order to prepare the data for use in a later model. These are not necessary for making the data meaningful and I won't describe them in detail, but the basic idea is to rewrite the stats from the offense's point of view. For instance, I'll make a new column for field position, ranging from -50, where the offense is at their own goal line, to 50, where the offense is an inch from scoring a touchdown.

# %%
def get_secs_played(play):
    try:
        if "OT" in str(play.quarter):
            qtr = 5
        else:
            qtr = int(play.quarter)
    except:
        qtr = 5
        
    try:
        mins_rem, secs_rem = str(play.qtr_time_remain).split(":")
    except:
        mins_rem = 15
        secs_rem = 0
        
    secs_played = 900*(qtr-1) + 900 - ( 60*int(mins_rem) + int(secs_rem) )
    return secs_played

# %%
def get_fieldpos_prefixes(df):
    sides = []
    fieldpos = [str(i) for i in df['location']]
    fieldpos = [i.split()[0] for i in fieldpos if i != '']
    for entry in fieldpos:
        if not entry in sides:
            sides.append(entry)
    
    if str(df['possession'].iloc[0]) == 'home':
        hm_side = sides[0]
        aw_side = sides[1]
    else:
        hm_side = sides[1]
        aw_side = sides[0]
        
    return hm_side, aw_side

# %%
def get_off_fieldpos(play, hm_side, aw_side):
    try:
        side, yardline = str(play.location).split()
        yardline = int(yardline)
        if str(play.possession) == "home":
            if side == hm_side:
                return -(50-yardline)
            elif side == aw_side:
                return 50-yardline
        elif str(play.possession) == "away":
            if side == hm_side:
                return 50-yardline
            elif side == aw_side:
                return -(50-yardline)
        return 0
    except:
        return 0

# %% [markdown]
# Now, finally, put all of the individual data cleaning functions together in one function.

# %%
def clean_game(df):
    
    # Drop non-play rows
    df = drop_nonplays(df)
    
    # Add column for possession
    df['possession'] = assign_possession(df)
        
    # Add column for the winning team
    df['winner'] = get_winner(df)
    
    # Add columns for score before plays happen
    get_score_before_plays(df)
    
    # Also rename pre-existing score columns
    df.rename( index=str, inplace=True, columns={
            "pbp_score_hm":"home_score_after",
            "pbp_score_aw":"away_score_after"})
    
    # Add column for seconds played
    df['secs_played'] = df.apply( 
        lambda row: get_secs_played(row),
        axis=1)
    
    # Add column for re-forumlated offensive field position
    hm_side, aw_side = get_fieldpos_prefixes(df)
    df['off_fieldpos'] = df.apply( 
        lambda row: get_off_fieldpos(row, hm_side, aw_side ),
        axis=1)
    
    return df

# %% [markdown]
# We should probably try using this to show that it all works properly.

# %%
pbp_df = clean_game(pbp_df)
pbp_df.head(10)
# Out:
# /home/evan/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#    quarter qtr_time_remain down yds_to_go location  \
# 2        1           15:00                  CIN 35
# 3        1           15:00    1        10   PIT 20
# 4        1           14:15    2         8   PIT 22
# 5        1           13:39    3         1   PIT 29
# 6        1           13:31    1        10   CIN 40
# 7        1           12:47    2         7   CIN 37
# 8        1           12:05    3         7   CIN 37
# 9        1           11:54    1        10   CIN 27
# 10       1           11:21    2        10   CIN 27
# 12       1           10:34    3         3   CIN 20
#
#                                                detail  away_score_after  \
# 2           Mike Nugent kicks off 65 yards, touchback                 0
# 3   DeAngelo Williams middle for 2 yards (tackle b...                 0
# 4   Ben Roethlisberger pass complete short left to...                 0
# 5   Ben Roethlisberger pass complete deep right to...                 0
# 6   DeAngelo Williams left guard for 3 yards (tack...                 0
# 7   Ben Roethlisberger pass complete short left to...                 0
# 8   Ben Roethlisberger pass complete short left to...                 0
# 9   DeAngelo Williams right end for no gain (tackl...                 0
# 10  DeAngelo Williams left tackle for 7 yards (tac...                 0
# 12  Ben Roethlisberger pass complete short middle ...                 0
#
#     home_score_after exp_pts_before exp_pts_after      ...      scoring_play  \
# 2                  0              0         -0.28      ...                 0
# 3                  0           0.28             0      ...                 0
# 4                  0              0          0.23      ...                 0
# 5                  0           0.23          2.92      ...                 0
# 6                  0           2.92          2.78      ...                 0
# 7                  0           2.78          2.08      ...                 0
# 8                  0           2.08          3.78      ...                 0
# 9                  0           3.78          3.23      ...                 0
# 10                 0           3.23          3.47      ...                 0
# 12                 0           3.47          6.97      ...                 0
#
#    change_of_poss  home_team  away_team possession winner home_score  \
# 2             1.0        CIN        PIT       home   away        0.0
# 3             0.0        CIN        PIT       away   away        0.0
# 4             0.0        CIN        PIT       away   away        0.0
# 5             0.0        CIN        PIT       away   away        0.0
# 6             0.0        CIN        PIT       away   away        0.0
# 7             0.0        CIN        PIT       away   away        0.0
# 8             0.0        CIN        PIT       away   away        0.0
# 9             0.0        CIN        PIT       away   away        0.0
# 10            0.0        CIN        PIT       away   away        0.0
# 12            0.0        CIN        PIT       away   away        0.0
#
#    away_score  secs_played  off_fieldpos
# 2         0.0            0           -15
# 3         0.0            0           -30
# 4         0.0           45           -28
# 5         0.0           81           -21
# 6         0.0           89            10
# 7         0.0          133            13
# 8         0.0          175            13
# 9         0.0          186            23
# 10        0.0          219            23
# 12        0.0          266            30
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Construct a loop to grab plays for many games
#
# Since that seems to work, the next step is to try and grab the same table from many pages. We can do this in generally the same way we looped over teams and seasons before; the key here is to get a list of games to loop over.
#
# Conveniently (necessarily), we already have that list from before, we just have to access it.

# %%
# Get info for who's playing in each game and what the boxscore url is
game_list = [ 
        str(row.box_url) for i, row in games_df.iterrows()
    ]

print(game_list[:5])
# Out:
# ['199609010car', '199609080atl', 'bye', '199609220atl', '199609290sfo']

# %% [markdown]
# We can loop through this list and grab the play-by-play data for each of these games. But we don't want to duplicate effort and each of these games is listed twice, so keep track of which urls have been used already.

# %%
# Arbitrarily limit the loop
games_to_search = game_list[:]

# List for play-by-play dataframes
pbp_list = []

# Keep track of which urls have been used already
urls_visited = []
for url in games_to_search:
    if (url not in urls_visited) and ('bye' not in url):
        
        # We haven't tried to find this game yet
        urls_visited.append(url)
        
        # Try to grab the game's play-by-play data
        print("Looking up "+url)
        pbp_soup = make_soup(boxscore_url(url))
        pbp_df = read_table(pbp_soup, "pbp")
        
        # Try to grab the game's spread
        spread_df = read_table(pbp_soup, "gameinfo")
        
        # If that was successful, clean the resulting dataframe
        if type(pbp_df) is int:
            print("Play-by-play Lookup unsuccessful")
        elif type(spread_df) is int:
            print("Spread Lookup unsuccessful")
        
        else:
            pbp_df = clean_game(pbp_df)
            
            # Pull out the spread
            spread_df = spread_df[ spread_df['info'].str.contains("Vegas") ]
            spread = spread_df.values[0,1]
            
            # Also make sure to keep track of game's unique id and spread
            pbp_df['game_url'] = url
            pbp_df['spread'] = spread
            
            # Add this dataframe to the list of individual game dfs
            pbp_list.append(pbp_df)
            
        # Wait a second before pinging again
        time.sleep(1)
        

# Make one big dataframe from all of the little ones
all_plays_df = pd.concat(pbp_list)
all_plays_df.to_csv("pbp_data.csv")
# Out:
# Looking up 199609010car
# /home/evan/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Looking up 199609080atl
# Looking up 199609220atl
# Looking up 199609290sfo
# Looking up 199610060det
# Looking up 199610130atl
# Looking up 199610200dal
# Looking up 199610270atl
# Looking up 199611030atl
# Looking up 199611100ram
# Looking up 199611170atl
# Looking up 199611240cin
# Looking up 199612020atl
# Looking up 199612080nor
# Looking up 199612150atl
# Looking up 199612220jax
# Looking up 199609010sfo
# Looking up 199609080nor
# Looking up 199609150cin
# Looking up 199609220nor
# Looking up 199609290rav
# Looking up 199610060nor
# Looking up 199610130nor
# Looking up 199610200car
# Looking up 199611030nor
# Looking up 199810250nor
# Looking up 199811010car
# Looking up 199811080min
# Looking up 199811150nor
# Looking up 199811220sfo
# Looking up 199811290mia
# Looking up 199812060nor
# Looking up 199812200crd
# Looking up 199812270nor
# Looking up 199809270car
# Looking up 199810110dal
# Looking up 199810180tam
# Looking up 199810250car
# Looking up 199811080sfo
# Looking up 199811150car
# Looking up 199811220ram
# Looking up 199811290nyj
# Looking up 199812060car
# Looking up 199812130car
# Looking up 199812200car
# Looking up 199812270clt
# Looking up 199809060min
# Looking up 199809130gnb
# Looking up 199809200tam
# Looking up 199809280det
# Looking up 199810040tam
# Looking up 199811010tam
# Looking up 199811080tam
# Looking up 199811150jax
# Looking up 199811220tam
# Looking up 199811290chi
# Looking up 199812070tam
# Looking up 199812130tam
# Looking up 199812190was
# Looking up 199812270cin
# Looking up 199809060nyg
# Looking up 199809130rai
# Looking up 199809210nyg
# Looking up 199809270sdg
# Looking up 199810180nyg
# Looking up 199811010was
# Looking up 199811080dal
# Looking up 199811150nyg
# Looking up 199811220nyg
# Looking up 199811300sfo
# Looking up 199812060crd
# Looking up 199812130nyg
# Looking up 199812200nyg
# Looking up 199812270phi
# Looking up 199809060dal
# Looking up 199809130den
# Looking up 199809270dal
# Looking up 199810040was
# Looking up 199810180chi
# Looking up 199811020phi
# Looking up 199811150crd
# Looking up 199811220dal
# Looking up 199811260dal
# Looking up 199812130kan
# Looking up 199812200dal
# Looking up 199812270dal
# Looking up 199901020dal
# Looking up 199809060phi
# Looking up 199809200crd
# Looking up 199809270phi
# Looking up 199810040den
# Looking up 199810110phi
# Looking up 199810180sdg
# Looking up 199811080phi
# Looking up 199811150was
# Looking up 199811290gnb
# Looking up 199812030phi
# Looking up 199812130phi
# Looking up 199809140was
# Looking up 199809200sea
# Looking up 199809270was
# Looking up 199810180min
# Looking up 199811080crd
# Looking up 199811220was
# Looking up 199811290rai
# Looking up 199812060was
# Looking up 199809130ram
# Looking up 199809200min
# Looking up 199809270chi
# Looking up 199810050gnb
# Looking up 199810250det
# Looking up 199811150min
# Looking up 199811220min
# Looking up 199812060min
# Looking up 199812130rav
# Looking up 199812200min
# Looking up 199812260oti
# Looking up 199901100min
# Looking up 199809060gnb
# Looking up 199809200cin
# Looking up 199810150det
# Looking up 199810250gnb
# Looking up 199811010gnb
# Looking up 199811090pit
# Looking up 199812130gnb
# Looking up 199812200gnb
# Looking up 199812270chi
# Looking up 199901030sfo
# Looking up 199809130det
# Looking up 199810040chi
# Looking up 199811010det
# Looking up 199811150det
# Looking up 199811260det
# Looking up 199812060jax
# Looking up 199812140sfo
# Looking up 199812270rav
# Looking up 199809060chi
# Looking up 199809130pit
# Looking up 199810110crd
# Looking up 199810250oti
# Looking up 199811080chi
# Looking up 199812200chi
# Looking up 199809130sea
# Looking up 199809270pit
# Looking up 199810040kan
# Looking up 199810110sea
# Looking up 199810250sdg
# Looking up 199811010sea
# Looking up 199811080sea
# Looking up 199811150rai
# Looking up 199811290sea
# Looking up 199812060nyj
# Looking up 199812130sea
# Looking up 199812200sea
# Looking up 199812270den
# Looking up 199809060sfo
# Looking up 199810040buf
# Looking up 199810180sfo
# Looking up 199810250ram
# Looking up 199812200nwe
# Looking up 199812270sfo
# Looking up 199809270ram
# Looking up 199810040crd
# Looking up 199811290kan
# Looking up 199812270crd
# Looking up 199809200buf
# Looking up 199810110ram
# Looking up 199810180mia
# Looking up 199812130ram
# Looking up 199809060rav
# Looking up 199809200mia
# Looking up 199810110cin
# Looking up 199810180pit
# Looking up 199810260kan
# Looking up 199811010pit
# Looking up 199811150oti
# Looking up 199811220pit
# Looking up 199812060pit
# Looking up 199812200pit
# Looking up 199812280jax
# Looking up 199809060cin
# Looking up 199809270rav
# Looking up 199810180oti
# Looking up 199810250rai
# Looking up 199811010cin
# Looking up 199811080jax
# Looking up 199811220cin
# Looking up 199811290cin
# Looking up 199812060cin
# Looking up 199812130clt
# Looking up 199809130nyj
# Looking up 199809200jax
# Looking up 199810110rav
# Looking up 199811010rav
# Looking up 199811080rav
# Looking up 199811150sdg
# Looking up 199811290rav
# Looking up 199812060oti
# Looking up 199809060sdg
# Looking up 199809130mia
# Looking up 199810110clt
# Looking up 199810180buf
# Looking up 199811010buf
# Looking up 199811080nyj
# Looking up 199811150buf
# Looking up 199811220buf
# Looking up 199811290nwe
# Looking up 199812130buf
# Looking up 199812190buf
# Looking up 199901020mia
# Looking up 199809200nyj
# Looking up 199810040nyj
# Looking up 199810190nwe
# Looking up 199811010kan
# Looking up 199811150clt
# Looking up 199811220oti
# Looking up 199812130mia
# Looking up 199812270nyj
# Looking up 199901100nyj
# Looking up 199901170den
# Looking up 199809060clt
# Looking up 199810120jax
# Looking up 199810250mia
# Looking up 199811080mia
# Looking up 199811230nwe
# Looking up 199812060rai
# Looking up 199812210mia
# Looking up 199901090den
# Looking up 199809070den
# Looking up 199809130nwe
# Looking up 199809200nwe
# Looking up 199810110nwe
# Looking up 199811010clt
# Looking up 199901030jax
# Looking up 199809130oti
# Looking up 199809270oti
# Looking up 199812130jax
# Looking up 199809130jax
# Looking up 199810250den
# Looking up 199810040clt
# Looking up 199809200rai
# Looking up 199811080den
# Looking up 199811160kan
# Looking up 199811220den
# Looking up 199811290sdg
# Looking up 199812060den
# Looking up 199901310den
# Play-by-play Lookup unsuccessful
# Looking up 199809060kan
# Looking up 199810110rai
# Looking up 199812200sdg
# Looking up 199812260rai
# Looking up 199809200kan
# Looking up 199811220sdg
# Looking up 199909120atl
# Looking up 199909200dal
# Looking up 199909260ram
# Looking up 199910030atl
# Looking up 199910100nor
# Looking up 199910170atl
# Looking up 199910250pit
# Looking up 199910310atl
# Looking up 199911070atl
# Looking up 199911210tam
# Looking up 199911280car
# Looking up 199912050atl
# Looking up 199912120sfo
# Looking up 199912190oti
# Looking up 199912260atl
# Looking up 200001030atl
# Looking up 199909120nor
# Looking up 199909190sfo
# Looking up 199910030chi
# Looking up 199910170nor
# Looking up 199910240nyg
# Looking up 199910310nor
# Looking up 199911070nor
# Looking up 199911140nor
# Looking up 200009100sdg
# Looking up 200009170sea
# Looking up 200009240nor
# Looking up 200010080chi
# Looking up 200010150nor
# Looking up 200010290crd
# Looking up 200011050nor
# Looking up 200011120car
# Looking up 200011190nor
# Looking up 200011260ram
# Looking up 200012030nor
# Looking up 200012100sfo
# Looking up 200012240nor
# Looking up 200012300nor
# Looking up 200101060min
# Looking up 200009030was
# Looking up 200009100sfo
# Looking up 200010010car
# Looking up 200010080car
# Looking up 200010220car
# Looking up 200011050ram
# Looking up 200011190min
# Looking up 200011270car
# Looking up 200012030car
# Looking up 200012100kan
# Looking up 200012170car
# Looking up 200012240rai
# Looking up 200009030nwe
# Looking up 200009100tam
# Looking up 200009170det
# Looking up 200009240tam
# Looking up 200010010was
# Looking up 200010090min
# Looking up 200010190tam
# Looking up 200010290tam
# Looking up 200011120tam
# Looking up 200011190chi
# Looking up 200011260tam
# Looking up 200012030tam
# Looking up 200012100mia
# Looking up 200012180tam
# Looking up 200012240gnb
# Looking up 200012310phi
# Looking up 200009030nyg
# Looking up 200009100phi
# Looking up 200009170chi
# Looking up 200009240nyg
# Looking up 200010010oti
# Looking up 200010150nyg
# Looking up 200010290nyg
# Looking up 200011050cle
# Looking up 200011120nyg
# Looking up 200011190nyg
# Looking up 200011260crd
# Looking up 200012030was
# Looking up 200012100nyg
# Looking up 200012170dal
# Looking up 200012230nyg
# Looking up 200101070nyg
# Looking up 200101140nyg
# Looking up 200101280nyg
# Looking up 200009030dal
# Looking up 200009100crd
# Looking up 200009180was
# Looking up 200009240dal
# Looking up 200010220dal
# Looking up 200010290dal
# Looking up 200011050phi
# Looking up 200011120dal
# Looking up 200011190rav
# Looking up 200011230dal
# Looking up 200012100dal
# Looking up 200012250oti
# Looking up 200009170gnb
# Looking up 200010080phi
# Looking up 200010150crd
# Looking up 200010220phi
# Looking up 200011120pit
# Looking up 200011190phi
# Looking up 200011260was
# Looking up 200012030phi
# Looking up 200012100cle
# Looking up 200012240phi
# Looking up 200009100det
# Looking up 200010150was
# Looking up 200010220jax
# Looking up 200010300was
# Looking up 200011050crd
# Looking up 200011200ram
# Looking up 200012160pit
# Looking up 200012240was
# Looking up 200009030min
# Looking up 200009100min
# Looking up 200009170nwe
# Looking up 200010010det
# Looking up 200010150chi
# Looking up 200010220min
# Looking up 200011060gnb
# Looking up 200011120min
# Looking up 200011300min
# Looking up 200012100ram
# Looking up 200012170min
# Looking up 200012240clt
# Looking up 200009030gnb
# Looking up 200009100buf
# Looking up 200009240crd
# Looking up 200010010gnb
# Looking up 200010080det
# Looking up 200010150gnb
# Looking up 200010290mia
# Looking up 200011190gnb
# Looking up 200012030chi
# Looking up 200012100gnb
# Looking up 200009240chi
# Looking up 200010290clt
# Looking up 200011050det
# Looking up 200011230det
# Looking up 200012170nyj
# Looking up 200012240det
# Looking up 200011050chi
# Looking up 200011120buf
# Looking up 200011260nyj
# Looking up 200012100chi
# Looking up 200012170sfo
# Looking up 200009030mia
# Looking up 200009100sea
# Looking up 200009240sdg
# Looking up 200010020kan
# Looking up 200010150sea
# Looking up 200010220rai
# Looking up 200010290sea
# Looking up 200011050sea
# Looking up 200011120jax
# Looking up 200011260sea
# Looking up 200012100den
# Looking up 200012160sea
# Looking up 200012230sea
# Looking up 200009170ram
# Looking up 200010010sfo
# Looking up 200010080sfo
# Looking up 200010290sfo
# Looking up 200011120sfo
# Looking up 200012030sdg
# Looking up 200012230den
# Looking up 200010080crd
# Looking up 200012030cin
# Looking up 200012100jax
# Looking up 200012170crd
# Looking up 200009040ram
# Looking up 200010010ram
# Looking up 200010220kan
# Looking up 200009030pit
# Looking up 200009170cle
# Looking up 200009240pit
# Looking up 200010010jax
# Looking up 200010080nyj
# Looking up 200010150pit
# Looking up 200010220pit
# Looking up 200010290rav
# Looking up 200011050oti
# Looking up 200011190pit
# Looking up 200011260cin
# Looking up 200012030pit
# Looking up 200012240sdg
# Looking up 200009030cle
# Looking up 200009100cin
# Looking up 200009240rai
# Looking up 200010010cle
# Looking up 200010150den
# Looking up 200010290cle
# Looking up 200011120cle
# Looking up 200011190oti
# Looking up 200011260rav
# Looking up 200012030jax
# Looking up 200012170cle
# Looking up 200009170jax
# Looking up 200009240rav
# Looking up 200010010cin
# Looking up 200010080cin
# Looking up 200010220cin
# Looking up 200011050cin
# Looking up 200011190nwe
# Looking up 200012100oti
# Play-by-play Lookup unsuccessful
# Looking up 200012170cin
# Looking up 200009100rav
# Looking up 200009170mia
# Looking up 200010080jax
# Looking up 200010220rav
# Looking up 200011120oti
# Looking up 200012100rav
# Looking up 200012240rav
# Looking up 200012310rav
# Looking up 200101070oti
# Looking up 200101140rai
# Looking up 200101280rav
# Play-by-play Lookup unsuccessful
# Looking up 200009030buf
# Looking up 200009170nyj
# Looking up 200010010buf
# Looking up 200010080mia
# Looking up 200010150buf
# Looking up 200010290buf
# Looking up 200011050nwe
# Looking up 200011190kan
# Looking up 200012030buf
# Looking up 200012110clt
# Looking up 200012170buf
# Looking up 200009110nyj
# Looking up 200010150nwe
# Looking up 200010230nyj
# Looking up 200011050nyj
# Looking up 200011120clt
# Looking up 200011190mia
# Looking up 200012030nyj
# Looking up 200012100rai
# Looking up 200009240mia
# Looking up 200011120sdg
# Looking up 200011260clt
# Looking up 200012170mia
# Looking up 200012240nwe
# Looking up 200012300mia
# Looking up 200101060rai
# Looking up 200010010den
# Looking up 200010080nwe
# Looking up 200010220clt
# Looking up 200012040nwe
# Looking up 200009100oti
# Looking up 200010160oti
# Looking up 200011260jax
# Looking up 200009250clt
# Looking up 200009030kan
# Looking up 200009100clt
# Looking up 200009170rai
# Looking up 200009240den
# Looking up 200010080sdg
# Looking up 200011130den
# Looking up 200011190den
# Looking up 200012170kan
# Looking up 200009030rai
# Looking up 200010150kan
# Looking up 200010290sdg
# Looking up 200011050rai
# Looking up 200009170kan
# Looking up 200011260sdg
# Looking up 200109090sfo
# Looking up 200109230atl
# Looking up 200109300crd
# Looking up 200110070atl
# Looking up 200110140atl
# Looking up 200110210nor
# Looking up 200111040atl
# Looking up 200111110atl
# Looking up 200111180gnb
# Looking up 200111250car
# Looking up 200112020atl
# Looking up 200112090atl
# Looking up 200112160clt
# Looking up 200112230atl
# Looking up 200112300mia
# Looking up 200201060ram
# Looking up 200109090buf
# Looking up 200109300nyg
# Looking up 200110070nor
# Looking up 200110140car
# Looking up 200110280ram
# Looking up 200111040nor
# Looking up 200111110sfo
# Looking up 200111180nor
# Looking up 200111250nwe
# Looking up 200112020nor
# Looking up 200112170nor
# Looking up 200112230tam
# Looking up 200112300nor
# Looking up 200201060nor
# Looking up 200109090min
# Looking up 200109300car
# Looking up 200110070sfo
# Looking up 200110210was
# Looking up 200110280car
# Looking up 200111040mia
# Looking up 200111110ram
# Looking up 200111180car
# Looking up 200112090buf
# Looking up 200112230car
# Looking up 200112300car
# Looking up 200201060car
# Looking up 200109090dal
# Looking up 200109300min
# Looking up 200110070tam
# Looking up 200110140oti
# Looking up 200110210tam
# Looking up 200110280tam
# Looking up 200111040gnb
# Looking up 200111110det
# Looking up 200111180tam
# Looking up 200111260ram
# Looking up 200112020cin
# Looking up 200112090tam
# Looking up 200112160chi
# Looking up 200112290tam
# Looking up 200201060tam
# Looking up 200201120phi
# Looking up 200109100den
# Looking up 200109230kan
# Looking up 200110070nyg
# Looking up 200110140ram
# Looking up 200110220nyg
# Looking up 200110280was
# Looking up 200111040nyg
# Looking up 200111110crd
# Looking up 200111190min
# Looking up 200111250nyg
# Looking up 200112090dal
# Looking up 200112150nyg
# Looking up 200112230nyg
# Looking up 200112300phi
# Looking up 200201060nyg
# Looking up 200109230dal
# Looking up 200109300phi
# Looking up 200110070rai
# Looking up 200110150dal
# Looking up 200110280dal
# Looking up 200111180dal
# Looking up 200111220dal
# Looking up 200112020was
# Looking up 200112160sea
# Looking up 200112230crd
# Looking up 200112300dal
# Looking up 200201060det
# Looking up 200109090phi
# Looking up 200109230sea
# Looking up 200110070phi
# Looking up 200110280phi
# Looking up 200111040crd
# Looking up 200111110phi
# Looking up 200111250phi
# Looking up 200111290kan
# Looking up 200112090phi
# Looking up 200112160was
# Looking up 200112220sfo
# Looking up 200201190chi
# Looking up 200201270ram
# Looking up 200109090sdg
# Looking up 200109240gnb
# Looking up 200109300was
# Looking up 200111040was
# Looking up 200111180den
# Looking up 200112090crd
# Looking up 200112230was
# Looking up 200201060was
# Looking up 200109230chi
# Looking up 200110140min
# Looking up 200110210min
# Looking up 200111250min
# Looking up 200112020pit
# Looking up 200112090min
# Looking up 200112160det
# Looking up 200112230min
# Looking up 200112300gnb
# Looking up 200201070rav
# Looking up 200109090gnb
# Looking up 200110140gnb
# Looking up 200111110chi
# Looking up 200111220det
# Looking up 200112030jax
# Looking up 200112090gnb
# Looking up 200112160oti
# Looking up 200112230gnb
# Looking up 200201130gnb
# Looking up 200201200ram
# Looking up 200109230cle
# Looking up 200110080det
# Looking up 200110210det
# Looking up 200110280det
# Looking up 200111040sfo
# Looking up 200111180crd
# Looking up 200112020chi
# Looking up 200112230pit
# Looking up 200112300det
# Looking up 200109090rav
# Looking up 200110140chi
# Looking up 200110210cin
# Looking up 200110280chi
# Looking up 200111040chi
# Looking up 200201060chi
# Looking up 200109090cle
# Looking up 200109300rai
# Looking up 200110070sea
# Looking up 200110140sea
# Looking up 200110280sea
# Looking up 200111110sea
# Looking up 200111180buf
# Looking up 200111250kan
# Looking up 200112020sea
# Looking up 200112090den
# Looking up 200112300sdg
# Looking up 200201060sea
# Looking up 200109230sfo
# Looking up 200110010nyj
# Looking up 200111250clt
# Looking up 200112020sfo
# Looking up 200112090ram
# Looking up 200112160sfo
# Looking up 200109230crd
# Looking up 200110210crd
# Looking up 200111250sdg
# Looking up 200112020rai
# Looking up 200109300ram
# Looking up 200110210nyj
# Looking up 200111180nwe
# Looking up 200112300ram
# Looking up 200202030ram
# Play-by-play Lookup unsuccessful
# Looking up 200109090jax
# Looking up 200109300buf
# Looking up 200110070pit
# Looking up 200110140kan
# Looking up 200110290pit
# Looking up 200111040pit
# Looking up 200111110cle
# Looking up 200111180pit
# Looking up 200111250oti
# Looking up 200112090pit
# Looking up 200112160rav
# Looking up 200112300cin
# Looking up 200201060pit
# Looking up 200201200pit
# Looking up 200201270pit
# Looking up 200109300jax
# Looking up 200110070cle
# Looking up 200110140cin
# Looking up 200110210cle
# Looking up 200111180rav
# Looking up 200111250cle
# Looking up 200112020cle
# Looking up 200112090nwe
# Looking up 200112160cle
# Looking up 200112300oti
# Looking up 200109090cin
# Looking up 200109230cin
# Looking up 200109300sdg
# Looking up 200111110jax
# Looking up 200111180cin
# Looking up 200112090cin
# Looking up 200112160nyj
# Looking up 200112230rav
# Looking up 200201060oti
# Looking up 200109300den
# Looking up 200110070rav
# Looking up 200110280rav
# Looking up 200111120oti
# Looking up 200111250jax
# Looking up 200112020rav
# Looking up 200201130mia
# Looking up 200109230clt
# Looking up 200110070buf
# Looking up 200110180jax
# Looking up 200110280sdg
# Looking up 200111040buf
# Looking up 200111110nwe
# Looking up 200111250buf
# Looking up 200112160buf
# Looking up 200112300nyj
# Looking up 200201060mia
# Looking up 200109090nyj
# Looking up 200109230nwe
# Looking up 200110140nyj
# Looking up 200111110nyj
# Looking up 200111180mia
# Looking up 200112020nyj
# Looking up 200112230clt
# Looking up 200201060rai
# Looking up 200201120rai
# Looking up 200109090oti
# Looking up 200109230mia
# Looking up 200110070mia
# Looking up 200111110clt
# Looking up 200112020mia
# Looking up 200112100mia
# Looking up 200112220nwe
# Looking up 200109300nwe
# Looking up 200110140nwe
# Looking up 200110210clt
# Looking up 200110280den
# Looking up 200201190nwe
# Looking up 200202030nwe
# Looking up 200109230jax
# Looking up 200111040oti
# Looking up 200112220rai
# Looking up 200112300jax
# Looking up 200110140clt
# Looking up 200110250kan
# Looking up 200201060clt
# Looking up 200110070den
# Looking up 200110210sdg
# Looking up 200111050rai
# Looking up 200111110den
# Looking up 200112160kan
# Looking up 200112300den
# Looking up 200109090kan
# Looking up 200111180rai
# Looking up 200112090rai
# Looking up 200112150sdg
# Looking up 200111040sdg
# Looking up 200112230kan
# Looking up 200209080gnb
# Looking up 200209150atl
# Looking up 200209220atl
# Looking up 200210060atl
# Looking up 200210130nyg
# Looking up 200210200atl
# Looking up 200210270nor
# Looking up 200211030atl
# Looking up 200211100pit
# Looking up 200211170atl
# Looking up 200211240car
# Looking up 200212010min
# Looking up 200212080tam
# Looking up 200212150atl
# Looking up 200212220atl
# Looking up 200212290cle
# Looking up 200301040gnb
# Looking up 200301110phi
# Looking up 200209080tam
# Looking up 200209150nor
# Looking up 200209220chi
# Looking up 200209290det
# Looking up 200210060nor
# Looking up 200210130was
# Looking up 200210200nor
# Looking up 200211100car
# Looking up 200211240nor
# Looking up 200212010nor
# Looking up 200212080rav
# Looking up 200212150nor
# Looking up 200212220cin
# Looking up 200212290nor
# Looking up 200209080car
# Looking up 200209150car
# Looking up 200209220min
# Looking up 200209290gnb
# Looking up 200210060car
# Looking up 200210130dal
# Looking up 200210270car
# Looking up 200211170tam
# Looking up 200212010cle
# Looking up 200212080car
# Looking up 200212150pit
# Looking up 200212220car
# Looking up 200209150rav
# Looking up 200209230tam
# Looking up 200209290cin
# Looking up 200210130tam
# Looking up 200210200phi
# Looking up 200211030tam
# Looking up 200211240tam
# Looking up 200212150det
# Looking up 200212230tam
# Looking up 200212290chi
# Looking up 200301120tam
# Looking up 200301190phi
# Looking up 200301260tam
# Play-by-play Lookup unsuccessful
# Looking up 200209050nyg
# Looking up 200209150ram
# Looking up 200209220nyg
# Looking up 200209290crd
# Looking up 200210060dal
# Looking up 200210280phi
# Looking up 200211030nyg
# Looking up 200211100min
# Looking up 200211170nyg
# Looking up 200211240htx
# Looking up 200212010nyg
# Looking up 200212080was
# Looking up 200212150nyg
# Looking up 200212220clt
# Looking up 200212280nyg
# Looking up 200301050sfo
# Looking up 200209080htx
# Looking up 200209150dal
# Looking up 200209220phi
# Looking up 200209290ram
# Looking up 200210200crd
# Looking up 200210270dal
# Looking up 200211030det
# Looking up 200211170clt
# Looking up 200211240dal
# Looking up 200211280dal
# Looking up 200212080dal
# Looking up 200212210dal
# Looking up 200212290was
# Looking up 200209080oti
# Looking up 200209160was
# Looking up 200209290phi
# Looking up 200210060jax
# Looking up 200211030chi
# Looking up 200211100phi
# Looking up 200211170phi
# Looking up 200211250sfo
# Looking up 200212010phi
# Looking up 200212080sea
# Looking up 200212150phi
# Looking up 200209080was
# Looking up 200209220sfo
# Looking up 200210060oti
# Looking up 200210200gnb
# Looking up 200210270was
# Looking up 200211030sea
# Looking up 200211100jax
# Looking up 200211240was
# Looking up 200212220was
# Looking up 200209080chi
# Looking up 200209150min
# Looking up 200209290sea
# Looking up 200210130min
# Looking up 200210200nyj
# Looking up 200210270min
# Looking up 200211170min
# Looking up 200211240nwe
# Looking up 200212080gnb
# Looking up 200212210min
# Looking up 200212290det
# Looking up 200209220det
# Looking up 200210070chi
# Looking up 200210130nwe
# Looking up 200211040gnb
# Looking up 200211100gnb
# Looking up 200212010gnb
# Looking up 200212150sfo
# Looking up 200212220gnb
# Looking up 200212290nyj
# Looking up 200209080mia
# Looking up 200210200det
# Looking up 200210270buf
# Looking up 200211170det
# Looking up 200211240chi
# Looking up 200211280det
# Looking up 200212080crd
# Looking up 200209290buf
# Looking up 200211100chi
# Looking up 200211180ram
# Looking up 200212090mia
# Looking up 200212150chi
# Looking up 200209080rai
# Looking up 200209150sea
# Looking up 200210140sea
# Looking up 200210200ram
# Looking up 200211100crd
# Looking up 200211170sea
# Looking up 200211240sea
# Looking up 200212010sfo
# Looking up 200212220sea
# Looking up 200212290sdg
# Looking up 200209150sfo
# Looking up 200210060sfo
# Looking up 200210270sfo
# Looking up 200211030rai
# Looking up 200211100sfo
# Looking up 200211170sdg
# Looking up 200212210crd
# Looking up 200212300ram
# Looking up 200209220crd
# Looking up 200211030crd
# Looking up 200211240crd
# Looking up 200212010kan
# Looking up 200212150ram
# Looking up 200212290den
# Looking up 200209080den
# Looking up 200210130ram
# Looking up 200211100ram
# Looking up 200212080kan
# Looking up 200209090nwe
# Looking up 200209150pit
# Looking up 200209290pit
# Looking up 200210130cin
# Looking up 200210210pit
# Looking up 200210270rav
# Looking up 200211030cle
# Looking up 200211170oti
# Looking up 200211240pit
# Looking up 200212010jax
# Looking up 200212080pit
# Looking up 200212290pit
# Looking up 200301050pit
# Looking up 200301110oti
# Looking up 200209080cle
# Looking up 200209150cle
# Looking up 200209220oti
# Looking up 200210060cle
# Looking up 200210200cle
# Looking up 200210270nyj
# Looking up 200211170cin
# Looking up 200212080jax
# Looking up 200212150cle
# Looking up 200212220rav
# Looking up 200209080cin
# Looking up 200210060clt
# Looking up 200210270cin
# Looking up 200211030htx
# Looking up 200211100rav
# Looking up 200212010cin
# Looking up 200212150cin
# Looking up 200212290buf
# Looking up 200209300rav
# Looking up 200210130clt
# Looking up 200210200rav
# Looking up 200211170mia
# Looking up 200211240rav
# Looking up 200212150htx
# Looking up 200209080buf
# Looking up 200209220den
# Looking up 200210060buf
# Looking up 200210130htx
# Looking up 200210200mia
# Looking up 200211030buf
# Looking up 200211170kan
# Looking up 200211240nyj
# Looking up 200212010buf
# Looking up 200212080nwe
# Looking up 200212150buf
# Looking up 200209150nyj
# Looking up 200209220mia
# Looking up 200209290jax
# Looking up 200210060nyj
# Looking up 200211030sdg
# Looking up 200211100nyj
# Looking up 200212020rai
# Looking up 200212080nyj
# Looking up 200212220nwe
# Looking up 200301040nyj
# Looking up 200301120rai
# Looking up 200209150clt
# Looking up 200209290kan
# Looking up 200210060mia
# Looking up 200210130den
# Looking up 200211240mia
# Looking up 200212150mia
# Looking up 200212290nwe
# Looking up 200209220nwe
# Looking up 200209290sdg
# Looking up 200210270nwe
# Looking up 200211170rai
# Looking up 200212160oti
# Looking up 200209290rai
# Looking up 200210130oti
# Looking up 200211030clt
# Looking up 200211100oti
# Looking up 200212080oti
# Looking up 200212220jax
# Looking up 200212290htx
# Looking up 200301190rai
# Looking up 200209080jax
# Looking up 200209150kan
# Looking up 200210270jax
# Looking up 200211170htx
# Looking up 200212290clt
# Looking up 200209220htx
# Looking up 200211240den
# Looking up 200212010clt
# Looking up 200209150sdg
# Looking up 200210060den
# Looking up 200210200kan
# Looking up 200211110den
# Looking up 200212010sdg
# Looking up 200212150den
# Looking up 200212220rai
# Looking up 200210200rai
# Looking up 200210270kan
# Looking up 200212080sdg
# Looking up 200212280rai
# Looking up 200301260rai
# Looking up 200210130sdg
# Looking up 200212220kan
# Looking up 200309070dal
# Looking up 200309140atl
# Looking up 200309210atl
# Looking up 200309280car
# Looking up 200310050atl
# Looking up 200310130ram
# Looking up 200310190atl
# Looking up 200311020atl
# Looking up 200311090nyg
# Looking up 200311160nor
# Looking up 200311230atl
# Looking up 200311300htx
# Looking up 200312070atl
# Looking up 200312140clt
# Looking up 200312200tam
# Looking up 200312280atl
# Looking up 200309070sea
# Looking up 200309140nor
# Looking up 200309210oti
# Looking up 200309280nor
# Looking up 200310050car
# Looking up 200310120nor
# Looking up 200310260nor
# Looking up 200311020tam
# Looking up 200311230phi
# Looking up 200311300was
# Looking up 200312070nor
# Looking up 200312140nor
# Looking up 200312210jax
# Looking up 200312280nor
# Looking up 200309070car
# Looking up 200309140tam
# Looking up 200310120clt
# Looking up 200310190car
# Looking up 200311020htx
# Looking up 200311090car
# Looking up 200311160car
# Looking up 200311230dal
# Looking up 200311300car
# Looking up 200312140crd
# Looking up 200312210car
# Looking up 200312280nyg
# Looking up 200401030car
# Looking up 200401100ram
# Looking up 200401180phi
# Looking up 200402010car
# Looking up 200309080phi
# Looking up 200310060tam
# Looking up 200310120was
# Looking up 200310190sfo
# Looking up 200310260tam
# Looking up 200311160tam
# Looking up 200311240tam
# Looking up 200311300jax
# Looking up 200312140tam
# Looking up 200312280oti
# Looking up 200309070nyg
# Looking up 200309150nyg
# Looking up 200309210was
# Looking up 200310050nyg
# Looking up 200310120nwe
# Looking up 200310190nyg
# Looking up 200310260min
# Looking up 200311020nyj
# Looking up 200311160phi
# Looking up 200311300nyg
# Looking up 200312070nyg
# Looking up 200312210dal
# Looking up 200309280nyj
# Looking up 200310050dal
# Looking up 200310120dal
# Looking up 200310190det
# Looking up 200311020dal
# Looking up 200311090dal
# Looking up 200311160nwe
# Looking up 200311270dal
# Looking up 200312070phi
# Looking up 200312140was
# Looking up 200309140phi
# Looking up 200309280buf
# Looking up 200310050phi
# Looking up 200310260phi
# Looking up 200311100gnb
# Looking up 200312150mia
# Looking up 200312210phi
# Looking up 200312270was
# Looking up 200401110phi
# Looking up 200309040was
# Looking up 200309280was
# Looking up 200310190buf
# Looking up 200311090was
# Looking up 200311230mia
# Looking up 200312210chi
# Looking up 200309070gnb
# Looking up 200309140min
# Looking up 200309210det
# Looking up 200309280min
# Looking up 200310190min
# Looking up 200311020min
# Looking up 200311090sdg
# Looking up 200311160rai
# Looking up 200311230min
# Looking up 200311300ram
# Looking up 200312070min
# Looking up 200312140chi
# Looking up 200312200min
# Looking up 200312280crd
# Looking up 200309140gnb
# Looking up 200309210crd
# Looking up 200309290chi
